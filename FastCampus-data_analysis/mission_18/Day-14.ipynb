# %%
# 필요한 Module을 Import 하세요

# %%
# 주어진 데이터를 불러오세요

# %% [markdown]
# ### 1. AR 모델을 이용하여 타임시리즈 예측 모델을 만드세요. (이전 12개월 데이터를 학습하도록 파라미터 설정)

# %%
# 정답 Code
# Hint: date는 index로 들어가있어야합니다.

# %% [markdown]
# ### 2. 학습된 AR모델을 이용하여, 향후 30개월 데이터를 예측하고 결과물을 Line plot으로 그려보세요

# %%
# 정답 Code

# %%
# 아래와 같은 형태가 나와야합니다.
# Out:
# C:\Users\Sean\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:152: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Int64Indexes with a unit increment support extending. The index is set will contain the position relative to the data length.
#   UserWarning,
# <AxesSubplot:ylabel='value'>
