# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.optimize as opt

import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from tensorflow import keras

from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

# %%
X, y = make_circles(n_samples=1000, noise=0.15, factor=0.6, random_state=40)

# %%
X = pd.DataFrame(X)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train = X_train*5.0
X_test = X_test*5.0

# %%
mask = y_train == 1
passed = plt.scatter(X_train[mask][0].values, X_train[mask][1].values, s=50, c='k', marker='+',)
failed = plt.scatter(X_train[~mask][0].values, X_train[~mask][1].values, s=50, c='y', marker='o',)
plt.xlabel('Microchip Test1')
plt.ylabel('Microchip Test2')
plt.legend((passed, failed), ('Accepted', 'Rejected'))
plt.show()

# %%
model_0000 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0000.summary()

model_0001 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0011 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0111 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_1111 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0002 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0022 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0222 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_2222 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0003 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0033 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0333 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_3333 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(1.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0004 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0044 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_0444 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(0.00)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

model_4444 = keras.models.Sequential([
    keras.Input(shape=(2, )),
    keras.layers.Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(10, activation='relu', kernel_regularizer=keras.regularizers.l2(3.0)),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])
# Out:
# Model: "sequential_238"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_952 (Dense)            (None, 16)                48
# _________________________________________________________________
# dense_953 (Dense)            (None, 10)                170
# _________________________________________________________________
# dense_954 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_955 (Dense)            (None, 10)                110
# _________________________________________________________________
# sigmoid_layer (Dense)        (None, 1)                 11
# ...
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_0000.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0001.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0011.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0111.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_1111.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

model_0002.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0022.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0222.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_2222.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

model_0003.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0033.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0333.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_3333.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

model_0004.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0044.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_0444.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_4444.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
epochs = 20

# verbose options
# 0 = silent, 
# 1 = progress bar, 
# 2 = one line per epoch.
verbose = 0

history_0000 = model_0000.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0001 = model_0001.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0011 = model_0011.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0111 = model_0111.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_1111 = model_1111.fit(X_train, y_train, epochs=epochs, verbose=verbose)

history_0002 = model_0002.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0022 = model_0022.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0222 = model_0222.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_2222 = model_2222.fit(X_train, y_train, epochs=epochs, verbose=verbose)

history_0003 = model_0003.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0033 = model_0033.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0333 = model_0333.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_3333 = model_3333.fit(X_train, y_train, epochs=epochs, verbose=verbose)

history_0004 = model_0004.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0044 = model_0044.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_0444 = model_0444.fit(X_train, y_train, epochs=epochs, verbose=verbose)
history_4444 = model_4444.fit(X_train, y_train, epochs=epochs, verbose=verbose)

# %%
print("0000 : ", history_0000.history['accuracy'][-3:])
print('\n')

print("0001 : ", history_0001.history['accuracy'][-3:])
print("0011 : ", history_0011.history['accuracy'][-3:])
print("0111 : ", history_0111.history['accuracy'][-3:])
print("1111 : ", history_1111.history['accuracy'][-3:])
print('\n')

print("0002 : ", history_0002.history['accuracy'][-3:])
print("0022 : ", history_0022.history['accuracy'][-3:])
print("0222 : ", history_0222.history['accuracy'][-3:])
print("2222 : ", history_2222.history['accuracy'][-3:])
print('\n')

print("0003 : ", history_0003.history['accuracy'][-3:])
print("0033 : ", history_0033.history['accuracy'][-3:])
print("0333 : ", history_0333.history['accuracy'][-3:])
print("3333 : ", history_3333.history['accuracy'][-3:])
print('\n')

print("0004 : ", history_0004.history['accuracy'][-3:])
print("0044 : ", history_0044.history['accuracy'][-3:])
print("0444 : ", history_0444.history['accuracy'][-3:])
print("4444 : ", history_4444.history['accuracy'][-3:])
# Out:
# 0000 :  [0.7971428632736206, 0.8257142901420593, 0.868571400642395]
#
#
# 0001 :  [0.8100000023841858, 0.8328571319580078, 0.8485714197158813]
# 0011 :  [0.9114285707473755, 0.8999999761581421, 0.9014285802841187]
# 0111 :  [0.9128571152687073, 0.9100000262260437, 0.9128571152687073]
# 1111 :  [0.8999999761581421, 0.9085714221000671, 0.9200000166893005]
#
#
# 0002 :  [0.8785714507102966, 0.8871428370475769, 0.9085714221000671]
# 0022 :  [0.7400000095367432, 0.6899999976158142, 0.7385714054107666]
# 0222 :  [0.5742856860160828, 0.581428587436676, 0.5828571319580078]
# 2222 :  [0.6171428561210632, 0.522857129573822, 0.5171428322792053]
#
#
# 0003 :  [0.8742856979370117, 0.8885714411735535, 0.8828571438789368]
# 0033 :  [0.7157142758369446, 0.6885714530944824, 0.6928571462631226]
# 0333 :  [0.5171428322792053, 0.5171428322792053, 0.5171428322792053]
# 3333 :  [0.5171428322792053, 0.5171428322792053, 0.5171428322792053]
#
#
# ...

# %%
result_0000 = model_0000.evaluate(X_test, y_test, verbose=verbose)

result_0001 = model_0001.evaluate(X_test, y_test, verbose=verbose)
result_0011 = model_0011.evaluate(X_test, y_test, verbose=verbose)
result_0111 = model_0111.evaluate(X_test, y_test, verbose=verbose)
result_1111 = model_1111.evaluate(X_test, y_test, verbose=verbose)

result_0002 = model_0002.evaluate(X_test, y_test, verbose=verbose)
result_0022 = model_0022.evaluate(X_test, y_test, verbose=verbose)
result_0222 = model_0222.evaluate(X_test, y_test, verbose=verbose)
result_2222 = model_2222.evaluate(X_test, y_test, verbose=verbose)

result_0003 = model_0003.evaluate(X_test, y_test, verbose=verbose)
result_0033 = model_0033.evaluate(X_test, y_test, verbose=verbose)
result_0333 = model_0333.evaluate(X_test, y_test, verbose=verbose)
result_3333 = model_3333.evaluate(X_test, y_test, verbose=verbose)

result_0004 = model_0004.evaluate(X_test, y_test, verbose=verbose)
result_0044 = model_0044.evaluate(X_test, y_test, verbose=verbose)
result_0444 = model_0444.evaluate(X_test, y_test, verbose=verbose)
result_4444 = model_4444.evaluate(X_test, y_test, verbose=verbose)

# %%
num_list = [0,0,0,0]

def print_result():
    for i in range(4):
        num_list = [0,0,0,0]
        for j in range(4):
            r = 'result_'
            num_list.pop(0)
            num_list.append(i+1)
            
            strings = [str(num) for num in num_list]
            a_string = "".join(strings)

            print(r + a_string)

# %%
print_result()
# Out:
# result_0001
# result_0011
# result_0111
# result_1111
# result_0002
# result_0022
# result_0222
# result_2222
# result_0003
# result_0033
# result_0333
# result_3333
# result_0004
# result_0044
# result_0444
# result_4444

# %%
print('*****Test Results*****')
print("0000 : ", str(round(result_0000[1], 2)*100) + '%')
print('\n')

print("0001 : ", str(round(result_0001[1], 2)*100) + '%')
print("0011 : ", str(round(result_0011[1], 2)*100) + '%')
print("0111 : ", str(round(result_0111[1], 2)*100) + '%')
print("1111 : ", str(round(result_1111[1], 2)*100) + '%')
print('\n')

print("0002 : ", str(round(result_0002[1], 2)*100) + '%')
print("0022 : ", str(round(result_0022[1], 2)*100) + '%')
print("0222 : ", str(round(result_0222[1], 2)*100) + '%')
print("2222 : ", str(round(result_2222[1], 2)*100) + '%')
print('\n')

print("0003 : ", str(round(result_0003[1], 2)*100) + '%')
print("0033 : ", str(round(result_0033[1], 2)*100) + '%')
print("0333 : ", str(round(result_0333[1], 2)*100) + '%')
print("3333 : ", str(round(result_3333[1], 2)*100) + '%')
print('\n')

print("0004 : ", str(round(result_0004[1], 2)*100) + '%')
print("0044 : ", str(round(result_0044[1], 2)*100) + '%')
print("0444 : ", str(round(result_0444[1], 2)*100) + '%')
print("4444 : ", str(round(result_4444[1], 2)*100) + '%')
# Out:
# *****Test Results*****
# 0000 :  84.0%
#
#
# 0001 :  84.0%
# 0011 :  89.0%
# 0111 :  86.0%
# 1111 :  88.0%
#
#
# 0002 :  87.0%
# 0022 :  67.0%
# 0222 :  54.0%
# 2222 :  46.0%
#
#
# 0003 :  88.0%
# 0033 :  66.0%
# 0333 :  46.0%
# 3333 :  46.0%
#
#
# 0004 :  64.0%
# 0044 :  82.0%
# 0444 :  46.0%
# 4444 :  46.0%

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:][0].min() - 2, X[:][0].max() + 2
    y_min, y_max = X[:][1].min() - 2, X[:][1].max() + 2
    h = 0.04
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])    # np.c_() : slice objects to concatenation along the second axis.
    Z = Z.reshape(xx.shape) < 0.5
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[:][0], X[:][1], c=y, cmap=plt.cm.Spectral)

# %%
# Best Model
# model_0011

print('[Test Error] - [Train Error] :', (history_0011.history['accuracy'][-1] - result_0011[1]))

plot_decision_boundary(lambda x: model_0011.predict(x), X_test, y_test)
plt.title("Neural Network 0011")
# Out:
# [Test Error] - [Train Error] : 0.014761924743652344
# Text(0.5, 1.0, 'Neural Network 0011')

# %%
plot_decision_boundary(lambda x: model_0000.predict(x), X_test, y_test)
plt.title("Neural Network 0000")
# Out:
# Text(0.5, 1.0, 'Neural Network 0000')

# %%
plot_decision_boundary(lambda x: model_0001.predict(x), X_test, y_test)
plt.title("Neural Network 0001")
# Out:
# Text(0.5, 1.0, 'Neural Network 0001')

# %%
plot_decision_boundary(lambda x: model_0002.predict(x), X_test, y_test)
plt.title("Neural Network 0002")
# Out:
# Text(0.5, 1.0, 'Neural Network 0002')

# %%
plot_decision_boundary(lambda x: model_0003.predict(x), X_test, y_test)
plt.title("Neural Network 0003")
# Out:
# Text(0.5, 1.0, 'Neural Network 0003')

# %%
plot_decision_boundary(lambda x: model_0004.predict(x), X_test, y_test)
plt.title("Neural Network 0004")
# Out:
# Text(0.5, 1.0, 'Neural Network 0004')
