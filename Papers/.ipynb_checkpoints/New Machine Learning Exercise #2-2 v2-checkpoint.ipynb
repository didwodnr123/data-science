# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.optimize as opt

import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from tensorflow import keras

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data/ex2data2.txt', header = None)
# or data = pd.read_csv(path, header=None, names=['test1','test2','accepted'])
X = data.iloc[:,:-1]
y = data.iloc[:,2]
data
# Out:
#             0         1  2
# 0    0.051267  0.699560  1
# 1   -0.092742  0.684940  1
# 2   -0.213710  0.692250  1
# 3   -0.375000  0.502190  1
# 4   -0.513250  0.465640  1
# ..        ...       ... ..
# 113 -0.720620  0.538740  0
# 114 -0.593890  0.494880  0
# 115 -0.484450  0.999270  0
# 116 -0.006336  0.999270  0
# 117  0.632650 -0.030612  0
#
# [118 rows x 3 columns]

# %%
mask = y == 1
passed = plt.scatter(X[mask][0].values, X[mask][1].values, s=50, c='k', marker='+',)
failed = plt.scatter(X[~mask][0].values, X[~mask][1].values, s=50, c='y', marker='o',)
plt.xlabel('Microchip Test1')
plt.ylabel('Microchip Test2')
plt.legend((passed, failed), ('Accepted', 'Rejected'))
plt.show()

# %%
model1 = keras.Sequential([
    keras.layers.Dense(2, activation='relu', name='relu_layer1'),
    keras.layers.Dense(2, activation='relu', name='relu_layer2'),
    keras.layers.Dense(1, activation='sigmoid', name='sigmoid_layer')
])

# %%
model1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model1.fit(X, y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.5318

# %%
xx = np.linspace(-1, 1.5, 50)
yy = np.linspace(-1, 1.5, 50)

X11 = []
X22 = []
pred = []
for point1 in xx:
    for point2 in yy:
        X11.append(point1)
        X22.append(point2)
        pred.append(model1.predict(np.array([point1, point2]).reshape(1,-1)))

# %%
f, ax1 = plt.subplots(figsize=(8, 6))
# ax1.contour(xx, yy, pred, levels=[0.5], cmap="Greys", vmin=0, vmax=.6)
ax1.scatter(X11, X22, c=pred, s=50, linewidth=1)

ax1.scatter(X.iloc[:,0], X.iloc[:, 1], c=y, s=50,
            cmap="RdBu", vmin=-.2, vmax=1.2,
            edgecolor="white", linewidth=1)

ax1.set(aspect="equal",
       xlim=(-1.0, 1.5), ylim=(-1.0, 1.5),
       xlabel="$X_1$", ylabel="$X_2$")
# Out:
# [None, (-1.0, 1.5), (-1.0, 1.5), Text(0.5, 0, '$X_1$'), Text(0, 0.5, '$X_2$')]

# %%
model2 = keras.Sequential([
    keras.layers.Dense(2, activation='relu', name='relu_layer1', 
                       kernel_regularizer=keras.regularizers.l2(1)),
    keras.layers.Dense(2, activation='relu', name='relu_layer2', 
                       kernel_regularizer=keras.regularizers.l2(1)),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model2.fit(X, y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 2.7790 - accuracy: 0.5115

# %%
model3 = keras.Sequential([
    keras.layers.Dense(2, activation='relu', name='relu_layer1', 
                       kernel_regularizer=keras.regularizers.l2(0)),
    keras.layers.Dense(2, activation='relu', name='relu_layer2', 
                       kernel_regularizer=keras.regularizers.l2(0)),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model3.fit(X, y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6795 - accuracy: 0.4839

# %%
model4 = keras.Sequential([
    keras.layers.Dense(2, activation='relu', name='relu_layer1', 
                       kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(2, activation='relu', name='relu_layer2', 
                       kernel_regularizer=keras.regularizers.l2(0.01)),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model4.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model4.fit(X, y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7641 - accuracy: 0.4648

# %%
model5 = keras.Sequential([
    keras.layers.Dense(2, activation='relu', name='relu_layer1', 
                       kernel_regularizer=keras.regularizers.l2(3)),
    keras.layers.Dense(2, activation='relu', name='relu_layer2', 
                       kernel_regularizer=keras.regularizers.l2(3)),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model5.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model5.fit(X, y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 7.9771 - accuracy: 0.4252

# %%
from sklearn.linear_model import LogisticRegression

# %%
skl_model = LogisticRegression()

# %%
skl_model.fit(X, y)
# Out:
# LogisticRegression()

# %%
skl_model.score(X, y)
# Out:
# 0.5423728813559322
